# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkwh/mario-snes-cnn-ppo/blob/main/train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jasonkwh/mario-snes-cnn-ppo.git
# %cd mario-snes-cnn-ppo
# %pip install -U gymnasium stable-retro stable-baselines3 opencv-python

# %%
# !python train.py
