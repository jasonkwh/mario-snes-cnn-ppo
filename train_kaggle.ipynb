# %% [markdown]
# # Train on Kaggle
#
# Kaggle pins Gymnasium 1.2.0 through `kaggle-environments`. This notebook uses the Kaggle-specific dependency set and leaves the preinstalled `dopamine-rl` package intact.

# %%
# !git clone https://github.com/jasonkwh/mario-snes-cnn-ppo.git
# %cd mario-snes-cnn-ppo
# %pip install -r requirements-kaggle.txt

# %%
# !python train.py
