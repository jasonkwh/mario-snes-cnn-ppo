# %% [markdown]
# # Train on Kaggle

# %%
# !git clone https://github.com/jasonkwh/mario-snes-cnn-ppo.git
# %cd mario-snes-cnn-ppo
# Kaggle preinstalls Dopamine, whose Gym requirement conflicts with stable-retro.
# %pip uninstall -y dopamine-rl
# %pip install -r requirements-kaggle.txt

# %%
# !python train.py
