# %% [markdown]
# # Train on Kaggle

# %%
# !git clone https://github.com/jasonkwh/mario-snes-cnn-ppo.git
# %cd mario-snes-cnn-ppo
# Kaggle preinstalls unused packages with incompatible requirements.
# %pip uninstall -y dopamine-rl mne
# %pip install -r requirements-kaggle.txt
# !cp "/kaggle/input/datasets/dongshenglalala/super-mario/super_mario.sfc" ./super_mario.sfc

# %%
# !python setup.py

# %%
# !python train.py
